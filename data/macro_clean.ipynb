# %%
import pandas as pd

# %%
df = pd.read_csv('macro.csv')
df.head()
# Out:
#          date       NFP     CPI  FederalRate  UnemploymentRate    PPI  \
# 0  2018-05-01  148755.0  0.4159          1.7               3.8  203.2
# 1  2018-05-02  148755.0  0.4159          1.7               3.8  203.2
# 2  2018-05-03  148755.0  0.4159          1.7               3.8  203.2
# 3  2018-05-04  148755.0  0.4159          1.7               3.8  203.2
# 4  2018-05-05  148755.0  0.4159          1.7               3.8  203.2
#
#        PCE       IPI  ConsumerSentiment  RetailSales  HousingStarts     HPI
# 0  13860.2  102.3911               98.0     500585.0         1358.0  202.46
# 1  13860.2  102.3911               98.0     500585.0         1358.0  202.46
# 2  13860.2  102.3911               98.0     500585.0         1358.0  202.46
# 3  13860.2  102.3911               98.0     500585.0         1358.0  202.46
# 4  13860.2  102.3911               98.0     500585.0         1358.0  202.46
