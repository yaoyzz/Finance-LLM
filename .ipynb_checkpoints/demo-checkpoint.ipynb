# %%
# import libraries
import requests
import json
import os
import re
from impo.impo import imp_inst as imp 
import datetime

imp.import_or_install('flask')
imp.import_or_install('pandas')
from flask import Flask, request, render_template, redirect, url_for, Markup
import pandas as pd
from lstm.lstm import Lstm
# Out:
# flask is already installed
# pandas is already installed
# pandas is already installed
# scikit-learn is not installed, installing now...
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-learn) (1.24.2)
# Requirement already satisfied: scipy>=1.3.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-learn) (3.1.0)
# scikit-learn has been installed
# numpy is already installed
# tensorflow is already installed
# keras is already installed
# matplotlib is already installed
# plotly is already installed

# %%
model_html = """
            <div class="work">
              <h2>Selected work</h2>
              <div class="work--lockup">
                <ul class="slider">
                  <li class="slider--item slider--item-left">
                    <a href="#0">
                      <div class="slider--item-image">
                        <img src="{{ url_for('static', filename='img/work-victory.jpg') }}" alt="Victory">
                      </div>
                      <p class="slider--item-title">Victory</p>
                      <p class="slider--item-description">Lorem ipsum dolor sit amet, consectetur adipisicing elit sed do.</p>
                    </a>
                  </li>
                  <li class="slider--item slider--item-center">
                    <a href="#0">
                      <div class="slider--item-image">
                        <img src="{{ url_for('static', filename='img/work-metiew-smith.jpg') }}" alt="Metiew and Smith">
                      </div>
                      <p class="slider--item-title">Metiew &amp; Smith</p>
                      <p class="slider--item-description">Lorem ipsum dolor sit amet, consectetur adipisicing elit sed do.</p>
                    </a>
                  </li>

                  <li class="slider--item slider--item-right">
                    <a href="#0">
                      <div class="slider--item-image">
                        <img src="{{ url_for('static', filename='img/work-alex-nowak.jpg') }}" alt="Alex Nowak">
                      </div>
                      <p class="slider--item-title">Alex Nowak</p>
                      <p class="slider--item-description">Lorem ipsum dolor sit amet, consectetur adipisicing elit sed do.</p>
                    </a>
                  </li>
                </ul>

                <div class="slider--prev">
                  <svg version="1.1" id="Layer_1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px"
                  viewBox="0 0 150 118" style="enable-background:new 0 0 150 118;" xml:space="preserve">
                  <g transform="translate(0.000000,118.000000) scale(0.100000,-0.100000)">
                    <path d="M561,1169C525,1155,10,640,3,612c-3-13,1-36,8-52c8-15,134-145,281-289C527,41,562,10,590,10c22,0,41,9,61,29
                    c55,55,49,64-163,278L296,510h575c564,0,576,0,597,20c46,43,37,109-18,137c-19,10-159,13-590,13l-565,1l182,180
                    c101,99,187,188,193,199c16,30,12,57-12,84C631,1174,595,1183,561,1169z"/>
                  </g>
                  </svg>
                </div>

                <div class="slider--next">
                  <svg version="1.1" id="Layer_1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px" viewBox="0 0 150 118" style="enable-background:new 0 0 150 118;" xml:space="preserve">
                  <g transform="translate(0.000000,118.000000) scale(0.100000,-0.100000)">
                    <path d="M870,1167c-34-17-55-57-46-90c3-15,81-100,194-211l187-185l-565-1c-431,0-571-3-590-13c-55-28-64-94-18-137c21-20,33-20,597-20h575l-192-193C800,103,794,94,849,39c20-20,39-29,61-29c28,0,63,30,298,262c147,144,272,271,279,282c30,51,23,60-219,304C947,1180,926,1196,870,1167z"/>
                  </g>
                  </svg>
                </div>
              </div>
            </div>
          """

# %%
predictions_html = """
<!DOCTYPE html>
<html lang="en">
<head>
  <title>Global</title>
  <meta charset="utf-8">
  <meta name="viewport" content="width=device-width, initial-scale=1">
  <meta http-equiv="X-UA-Compatible" content="IE=edge">
  <meta name="description" content="HTML5 website template">
  <meta name="keywords" content="global, template, html, sass, jquery">
  <meta name="author" content="Bucky Maler">
  <link rel="stylesheet" href="{{ url_for('static', filename='css/main.css') }}">
</head>
<body>

<!-- notification for small viewports and landscape oriented smartphones -->
<div class="device-notification">
  <a class="device-notification--logo" href="#0">
    <img src="{{ url_for('static', filename='img/logo.png') }}" alt="Global">
    <p>Global</p>
  </a>
  <p class="device-notification--message">Global has so much to offer that we must request you orient your device to portrait or find a larger screen. You won't be disappointed.</p>
</div>

<div class="perspective effect-rotate-left">
  <div class="container"><div class="outer-nav--return"></div>
    <div id="viewport" class="l-viewport">
      <div class="l-wrapper">
        <header class="header">
          <a class="header--logo" href="#0">
            <img src="{{ url_for('static', filename='img/logo.png') }}" alt="Global">
            <p>Global</p>
          </a>
          <button class="header--cta cta">Hire Us</button>
          <div class="header--nav-toggle">
            <span></span>
          </div>
        </header>
        <nav class="l-side-nav">
          <ul class="side-nav">
            <li class="is-active"><span>Home</span></li>
            <li class="is-active"><span>Predictions</span></li>
          </ul>
        </nav>
        <ul class="l-main-content main-content">
          <li class="l-section section section--is-active">
            <div class="intro">
              <div class="intro--banner">
                <h1>Predict<br>Stocks</h1>
                <button class="cta">Predict
                  <svg version="1.1" id="Layer_1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px" viewBox="0 0 150 118" style="enable-background:new 0 0 150 118;" xml:space="preserve">
                  <g transform="translate(0.000000,118.000000) scale(0.100000,-0.100000)">
                    <path d="M870,1167c-34-17-55-57-46-90c3-15,81-100,194-211l187-185l-565-1c-431,0-571-3-590-13c-55-28-64-94-18-137c21-20,33-20,597-20h575l-192-193C800,103,794,94,849,39c20-20,39-29,61-29c28,0,63,30,298,262c147,144,272,271,279,282c30,51,23,60-219,304C947,1180,926,1196,870,1167z"/>
                  </g>
                  </svg>
                  <span class="btn-background"></span>
                </button>
                <img src="{{ url_for('static', filename='img/introduction-visual.png') }}" alt="Welcome">
              </div>

              <form method="POST" action="/demo">
                <label for="stock-name">Stocks:</label>
                    <input type="text" id="stock-search" placeholder="Search stocks">
                    <div id="stock-checkboxes">
                        
                            <label>
                                <input type="checkbox" name="stock-name" value="MSFT">
                                Microsoft
                            </label>
                            <label>
                                <input type="checkbox" name="stock-name" value="JNJ">
                                Johnson & Johnson
                            </label>
                            <label>
                                <input type="checkbox" name="stock-name" value="INTC">
                                Intel Corporation
                            </label>
                            <label>
                                <input type="checkbox" name="stock-name" value="BA">
                                Boeing Co
                            </label>
                            <label>
                                <input type="checkbox" name="stock-name" value="UNH">
                                UnitedHealth Group Inc
                            </label>
                            <label>
                                <input type="checkbox" name="stock-name" value="JPM">
                                JPMorgan Chase & Co
                            </label>
                            <label>
                                <input type="checkbox" name="stock-name" value="V">
                                Visa Inc
                            </label>
                            <label>
                                <input type="checkbox" name="stock-name" value="PG">
                                Procter & Gamble Co
                            </label>
                            <label>
                                <input type="checkbox" name="stock-name" value="HD">
                                Home Depot Inc
                            </label>
                            <label>
                                <input type="checkbox" name="stock-name" value="CVX">
                                Chevron Corp
                            </label>
                            <label>
                                <input type="checkbox" name="stock-name" value="MRK">
                                Merck & Co Inc
                            </label>
                            <label>
                                <input type="checkbox" name="stock-name" value="KO">
                                Coca-Cola Co
                            </label>
                            <label>
                                <input type="checkbox" name="stock-name" value="CSCO">
                                Cisco Systems Inc
                            </label>
                            <label>
                                <input type="checkbox" name="stock-name" value="MCD">
                                McDonald's Corp
                            </label>
                            <label>
                                <input type="checkbox" name="stock-name" value="WMT">
                                Walmart Inc
                            </label>
                            <label>
                                <input type="checkbox" name="stock-name" value="CRM">
                                Salesforce.com Inc
                            </label>
                            <label>
                                <input type="checkbox" name="stock-name" value="DIS">
                                The Walt Disney Co
                            </label>
                            <label>
                                <input type="checkbox" name="stock-name" value="VZ">
                                Verizon Communications Inc
                            </label>
                            <label>
                                <input type="checkbox" name="stock-name" value="NKE">
                                Nike Inc
                            </label>
                            <label>
                                <input type="checkbox" name="stock-name" value="AAPL">
                                Apple Inc
                            </label>
                            <label>
                                <input type="checkbox" name="stock-name" value="IBM">
                                International Business Machines Corp
                            </label>
                            <label>
                                <input type="checkbox" name="stock-name" value="GS">
                                Goldman Sachs Group Inc
                            </label>
                            <label>
                                <input type="checkbox" name="stock-name" value="HON">
                                Honeywell International Inc
                            </label>
                            <label>
                                <input type="checkbox" name="stock-name" value="AXP">
                                American Express Co
                            </label>
                            <label>
                                <input type="checkbox" name="stock-name" value="AMGN">
                                Amgen, Inc.
                            </label>

                            <!-- <button class="cta">Predict
                                <svg version="1.1" id="Layer_1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px" viewBox="0 0 150 118" style="enable-background:new 0 0 150 118;" xml:space="preserve">
                                <g transform="translate(0.000000,118.000000) scale(0.100000,-0.100000)">
                                <path d="M870,1167c-34-17-55-57-46-90c3-15,81-100,194-211l187-185l-565-1c-431,0-571-3-590-13c-55-28-64-94-18-137c21-20,33-20,597-20h575l-192-193C800,103,794,94,849,39c20-20,39-29,61-29c28,0,63,30,298,262c147,144,272,271,279,282c30,51,23,60-219,304C947,1180,926,1196,870,1167z"/>
                                </g>
                                </svg>
                                <span class="btn-background"></span>
                            </button> -->
                        </div>


                        <label for="time-name" style="margin-bottom: 0px;">Time range predictions:</label>
                        <!-- <input type="text" id="source-search" placeholder="Select the source"> -->
                        <div id="time-checkboxes" style="margin-top: 0px; margin-bottom: 10px;">
                            
                                <label>
                                    <input type="radio" name="time-name" value="3">
                                    3 Months
                                </label>
                                <label>
                                    <input type="radio" name="time-name" value="6">
                                    6 Months
                                </label>
                                

                                <!-- <button class="cta">Predict
                                    <svg version="1.1" id="Layer_1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px" viewBox="0 0 150 118" style="enable-background:new 0 0 150 118;" xml:space="preserve">
                                    <g transform="translate(0.000000,118.000000) scale(0.100000,-0.100000)">
                                    <path d="M870,1167c-34-17-55-57-46-90c3-15,81-100,194-211l187-185l-565-1c-431,0-571-3-590-13c-55-28-64-94-18-137c21-20,33-20,597-20h575l-192-193C800,103,794,94,849,39c20-20,39-29,61-29c28,0,63,30,298,262c147,144,272,271,279,282c30,51,23,60-219,304C947,1180,926,1196,870,1167z"/>
                                    </g>
                                    </svg>
                                    <span class="btn-background"></span>
                                </button> -->
                            </div>

                            <!-- <label for="model-name" style="margin-bottom: 10px;">Models:</label>
                            <div id="model-checkboxes" style="margin-top: 0px; margin-bottom: 10px;">
                                
                                    <label>
                                        <input type="checkbox" name="model-name" value="Model 1">
                                        Model 1
                                    </label>
                                    <label>
                                        <input type="checkbox" name="model-name" value="Model 2">
                                        Model 2
                                    </label>
                                    <label>
                                        <input type="checkbox" name="model-name" value="Model 3">
                                        Model 3
                                    </label>
                                    <label>
                                        <input type="checkbox" name="model-name" value="Model 4">
                                        Model 4
                                    </label> -->
                                    
    
                                    <!-- <button class="cta">Predict
                                        <svg version="1.1" id="Layer_1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px" viewBox="0 0 150 118" style="enable-background:new 0 0 150 118;" xml:space="preserve">
                                        <g transform="translate(0.000000,118.000000) scale(0.100000,-0.100000)">
                                        <path d="M870,1167c-34-17-55-57-46-90c3-15,81-100,194-211l187-185l-565-1c-431,0-571-3-590-13c-55-28-64-94-18-137c21-20,33-20,597-20h575l-192-193C800,103,794,94,849,39c20-20,39-29,61-29c28,0,63,30,298,262c147,144,272,271,279,282c30,51,23,60-219,304C947,1180,926,1196,870,1167z"/>
                                        </g>
                                        </svg>
                                        <span class="btn-background"></span>
                                    </button> -->
                                <!-- </div> -->
                               <div>
                                <label for="model-name-toggle" style="margin-bottom: 10px;">Models:</label>
                            </div>
                                <label class="switch">
                                    <input type="checkbox" id="model-name-toggle" name="model-name-toggle">
                                    <span class="slider"></span>
                                </label>
                                <div id="model-bars" style="margin-top: 0px; margin-bottom: 20px; display: none;">
                                    <label for="model-1">Number of LSTM Layers:</label>
                                    <input type="range" id="model-1" name="model-1" min="2" max="100" value="6">
                                    <span id="model-1-value">6</span><br>
                                    
                                    <label for="model-2">Learning Rate:</label>
                                    <input type="range" id="model-2" name="model-2" min="0.001" max="0.1" value="0.01" step="0.001">
                                    <span id="model-2-value">0.01</span><br>
                                    
                                    <label for="model-3">Early Stopping:</label>
                                    <input type="range" id="model-3" name="model-3" min="10" max="500" value="200">
                                    <span id="model-3-value">200</span><br>
                                    
                                    <label for="model-4">Number of Epochs:</label>
                                    <input type="range" id="model-4" name="model-4" min="500" max="5000" value="2000">
                                    <span id="model-4-value">2000</span><br>
                                </div>
                                

                                <script>
                                    var toggle = document.getElementById("model-name-toggle");
                                    var checkboxes = document.getElementById("model-bars");
                                    toggle.addEventListener("change", function() {
                                        if (toggle.checked) {
                                            checkboxes.style.display = "block";
                                        } else {
                                            checkboxes.style.display = "none";
                                        }
                                    });


                                    const model1Range = document.getElementById('model-1');
                                    const model1Value = document.getElementById('model-1-value');

                                    model1Range.addEventListener('input', function() {
                                    model1Value.textContent = model1Range.value;
                                    });

                                    const model2Range = document.getElementById('model-2');
                                    const model2Value = document.getElementById('model-2-value');

                                    model2Range.addEventListener('input', function() {
                                    model2Value.textContent = model2Range.value;
                                    });

                                    const model3Range = document.getElementById('model-3');
                                    const model3Value = document.getElementById('model-3-value');

                                    model3Range.addEventListener('input', function() {
                                    model3Value.textContent = model3Range.value;
                                    });

                                    const model4Range = document.getElementById('model-4');
                                    const model4Value = document.getElementById('model-4-value');

                                    model4Range.addEventListener('input', function() {
                                    model4Value.textContent = model4Range.value;
                                    });

                                    const stockCheckboxes = document.querySelectorAll('#stock-checkboxes label');
                                    const stockSearch = document.querySelector('#stock-search');

                                    stockSearch.addEventListener('input', () => {
                                    const searchText = stockSearch.value.toLowerCase();
                                    stockCheckboxes.forEach((checkbox) => {
                                        const stockName = checkbox.textContent.trim().toLowerCase();
                                        checkbox.style.display = stockName.includes(searchText) ? 'block' : 'none';
                                    });
                                    });



                                </script>

                                <style>

                                .switch {
                                    position: relative;
                                    display: inline-block;
                                    width: 60px;
                                    height: 34px;
                                    margin-right: 10px;
                                    margin-top: 10px;
                                    margin-bottom: 10px;
                                  }
                                  
                                  .switch input {
                                    opacity: 0;
                                    width: 0;
                                    height: 0;
                                  }
                                  
                                  .slider {
                                    position: absolute;
                                    cursor: pointer;
                                    top: 0;
                                    left: 0;
                                    right: 0;
                                    bottom: 0;
                                    background-color: #ccc;
                                    -webkit-transition: .4s;
                                    transition: .4s;
                                    border-radius: 34px;
                                  }
                                  
                                  .slider:before {
                                    position: absolute;
                                    content: "";
                                    height: 26px;
                                    width: 26px;
                                    left: 4px;
                                    bottom: 4px;
                                    background-color: white;
                                    -webkit-transition: .4s;
                                    transition: .4s;
                                    border-radius: 50%;
                                  }
                                  
                                  input:checked + .slider {
                                    background-color: #2196F3;
                                  }
                                  
                                  input:focus + .slider {
                                    box-shadow: 0 0 1px #2196F3;
                                  }
                                  
                                  input:checked + .slider:before {
                                    -webkit-transform: translateX(26px);
                                    -ms-transform: translateX(26px);
                                    transform: translateX(26px);
                                  }
                                  
                                  .slider.round {
                                    border-radius: 34px;
                                  }
                                  
                                  .slider.round:before {
                                    border-radius: 50%;
                                  }
                                  
                                  .switch-text {
                                    display: inline-block;
                                    vertical-align: middle;
                                  }
                                  #more-models {
                                    display: none;
                                  }
                                  
                                  input:checked ~ #more-models {
                                    display: block;
                                  }
                                </style>

                        <style>
                            #stock-checkboxes {
                                overflow-x: auto;
                                white-space: nowrap;
                                margin-top: 10px;
                                margin-bottom: 10px;
                                border: 1px solid #ccc;
                                padding: 10px;
                                max-height: 150px;
                                overflow-y: auto;
                            }
                        
                            #stock-search {
                                background-color: black;
                                color: #f2f2f2;
                                border: 1px solid #ccc;
                                border-radius: 4px;
                                width: 100%;
                                padding: 5px;
                                box-sizing: border-box;
                                margin-bottom: 10px;
                            }
                        
                            #search-stock {
                                background-color: #f2f2f2;
                                color: black;
                                border: 1px solid #ccc;
                                border-radius: 4px;
                                width: 100%;
                                padding: 5px;
                                box-sizing: border-box;
                                margin-bottom: 10px;
                            }
                        </style>
                        


                        <!-- <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script> -->
                        <!-- <script>
                            $(document).ready(function() {
                                // Initialize search
                                // $('#stock-search').on('keyup', function() {
                                // var value = $(this).val().toLowerCase();
                                // $('#stock-checkboxes label').filter(function() {
                                //     $(this).toggle($(this).text().toLowerCase().indexOf(value) > -1)
                                // });

                                $('#source-search').on('keyup', function() {
                                var value = $(this).val().toLowerCase();
                                $('#source-checkboxes label').filter(function() {
                                    $(this).toggle($(this).text().toLowerCase().indexOf(value) > -1)
                                });

                                $('#model-search').on('keyup', function() {
                                var value = $(this).val().toLowerCase();
                                $('#model-checkboxes label').filter(function() {
                                    $(this).toggle($(this).text().toLowerCase().indexOf(value) > -1)
                                });
                                });

                                // Initialize checkboxes
                                $('#stock-checkboxes input[type=checkbox]').change(function() {
                                var selected = $('#stock-checkboxes input[type=checkbox]:checked');
                                var values = $.map(selected, function(checkbox) {
                                    return $(checkbox).val();
                                });
                                console.log(values);
                                });

                                $('#source-checkboxes input[type=checkbox]').change(function() {
                                var selected = $('#source-checkboxes input[type=checkbox]:checked');
                                var values = $.map(selected, function(checkbox) {
                                    return $(checkbox).val();
                                });
                                console.log(values);
                                });

                                $('#model-checkboxes input[type=checkbox]').change(function() {
                                var selected = $('#model-checkboxes input[type=checkbox]:checked');
                                var values = $.map(selected, function(checkbox) {
                                    return $(checkbox).val();
                                });
                                console.log(values);
                                });
                            });
                        </script> -->

                        <button class="cta" id="search-stock" name="search-stock" style="width:100%">Search
                            
                        </button>
                        
                    


                    
                    

                    
                </div>
              </form>
                
            </li>
        
        <!-- <script>
            const applymtch = document.getElementById("search-stock");

            applymtch.addEventListener("click", () => {
                const name = Array.from(document.getElementById("stock-name").selectedOptions).map(option => option.value);
                const source = Array.from(document.getElementById("source-name").selectedOptions).map(option => option.value);
                const model = Array.from(document.getElementById("model-name").selectedOptions).map(option => option.value);

                const matches = { name, source, model };

                localStorage.setItem("matches", JSON.stringify(matches));
            });

            // Retrieve the selections on page load
            const matches = JSON.parse(localStorage.getItem("matches"));
            if (matches) {
                matches.category.forEach(value => document.querySelector(`#stock-name option[value='${value}']`).selected = true);
                matches.category.forEach(value => document.querySelector(`#source-name option[value='${value}']`).selected = true);
                matches.category.forEach(value => document.querySelector(`#model-name option[value='${value}']`).selected = true);
            }
        </script> -->

        


          <li class="l-section section">
            <div class="work">
              <h2>Selected work</h2>
              <div class="work--lockup">
                <ul class="slider">
                  <li class="slider--item slider--item-left">
                    <a href="#0">
                      <div class="slider--item-image">
                        <img src="{{ url_for('static', filename='img/SPY.png') }}" alt="Victory">
                      </div>
                      <p class="slider--item-title">Victory</p>
                      <p class="slider--item-description">Lorem ipsum dolor sit amet, consectetur adipisicing elit sed do.</p>
                    </a>
                  </li>
                  <li class="slider--item slider--item-center">
                    <a href="#0">
                      <div class="slider--item-image">
                        <img src="{{ url_for('static', filename='img/work-metiew-smith.jpg') }}" alt="Metiew and Smith">
                      </div>
                      <p class="slider--item-title">Metiew &amp; Smith</p>
                      <p class="slider--item-description">Lorem ipsum dolor sit amet, consectetur adipisicing elit sed do.</p>
                    </a>
                  </li>

                  <li class="slider--item slider--item-right">
                    <a href="#0">
                      <div class="slider--item-image">
                        <img src="{{ url_for('static', filename='img/work-alex-nowak.jpg') }}" alt="Alex Nowak">
                      </div>
                      <p class="slider--item-title">Alex Nowak</p>
                      <p class="slider--item-description">Lorem ipsum dolor sit amet, consectetur adipisicing elit sed do.</p>
                    </a>
                  </li>
                </ul>

                <div class="slider--prev">
                  <svg version="1.1" id="Layer_1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px"
                  viewBox="0 0 150 118" style="enable-background:new 0 0 150 118;" xml:space="preserve">
                  <g transform="translate(0.000000,118.000000) scale(0.100000,-0.100000)">
                    <path d="M561,1169C525,1155,10,640,3,612c-3-13,1-36,8-52c8-15,134-145,281-289C527,41,562,10,590,10c22,0,41,9,61,29
                    c55,55,49,64-163,278L296,510h575c564,0,576,0,597,20c46,43,37,109-18,137c-19,10-159,13-590,13l-565,1l182,180
                    c101,99,187,188,193,199c16,30,12,57-12,84C631,1174,595,1183,561,1169z"/>
                  </g>
                  </svg>
                </div>

                <div class="slider--next">
                  <svg version="1.1" id="Layer_1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px" viewBox="0 0 150 118" style="enable-background:new 0 0 150 118;" xml:space="preserve">
                  <g transform="translate(0.000000,118.000000) scale(0.100000,-0.100000)">
                    <path d="M870,1167c-34-17-55-57-46-90c3-15,81-100,194-211l187-185l-565-1c-431,0-571-3-590-13c-55-28-64-94-18-137c21-20,33-20,597-20h575l-192-193C800,103,794,94,849,39c20-20,39-29,61-29c28,0,63,30,298,262c147,144,272,271,279,282c30,51,23,60-219,304C947,1180,926,1196,870,1167z"/>
                  </g>
                  </svg>
                </div>
              </div>
            </div>
          </li>
        </ul>
      </div>
    </div>
  </div>
  <ul class="outer-nav">
    <li class="is-active">Home</li>
    <li >Predictions</li>
  </ul>
</div>

<script src="https://ajax.googleapis.com/ajax/libs/jquery/2.2.4/jquery.min.js"></script>
<script>window.jQuery || document.write("<script src='{{ url_for('static', filename='js/vendor/jquery-2.2.4.min.js') }}'><\/script>")</script>
<script src="{{ url_for('static', filename='js/functions-min.js') }}"></script>
</body>
</html>
"""

# %%
def render_predictions(tickers):
    predictions_html = """
    <!DOCTYPE html>
    <html lang="en">
    <head>
      <title>Global</title>
      <meta charset="utf-8">
      <meta name="viewport" content="width=device-width, initial-scale=1">
      <meta http-equiv="X-UA-Compatible" content="IE=edge">
      <meta name="description" content="HTML5 website template">
      <meta name="keywords" content="global, template, html, sass, jquery">
      <meta name="author" content="Bucky Maler">
      <link rel="stylesheet" href="{{ url_for('static', filename='css/main.css') }}">
    </head>
    <body>

    <!-- notification for small viewports and landscape oriented smartphones -->
    <div class="device-notification">
      <a class="device-notification--logo" href="#0">
        <img src="{{ url_for('static', filename='img/logo.png') }}" alt="Global">
        <p>Global</p>
      </a>
      <p class="device-notification--message">Global has so much to offer that we must request you orient your device to portrait or find a larger screen. You won't be disappointed.</p>
    </div>

    <div class="perspective effect-rotate-left">
      <div class="container"><div class="outer-nav--return"></div>
        <div id="viewport" class="l-viewport">
          <div class="l-wrapper">
            <header class="header">
              <a class="header--logo" href="#0">
                <img src="{{ url_for('static', filename='img/logo.png') }}" alt="Global">
                <p>Global</p>
              </a>
              <button class="header--cta cta">Hire Us</button>
              <div class="header--nav-toggle">
                <span></span>
              </div>
            </header>
            <nav class="l-side-nav">
              <ul class="side-nav">
                <li class="is-active"><span>Home</span></li>
                <li class="is-active"><span>Predictions</span></li>
              </ul>
            </nav>
            <ul class="l-main-content main-content">
              <li class="l-section section section--is-active">
                <div class="intro">
                  <div class="intro--banner">
                    <h1>Predict<br>Stocks</h1>
                    <button class="cta">Predict
                      <svg version="1.1" id="Layer_1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px" viewBox="0 0 150 118" style="enable-background:new 0 0 150 118;" xml:space="preserve">
                      <g transform="translate(0.000000,118.000000) scale(0.100000,-0.100000)">
                        <path d="M870,1167c-34-17-55-57-46-90c3-15,81-100,194-211l187-185l-565-1c-431,0-571-3-590-13c-55-28-64-94-18-137c21-20,33-20,597-20h575l-192-193C800,103,794,94,849,39c20-20,39-29,61-29c28,0,63,30,298,262c147,144,272,271,279,282c30,51,23,60-219,304C947,1180,926,1196,870,1167z"/>
                      </g>
                      </svg>
                      <span class="btn-background"></span>
                    </button>
                    <img src="{{ url_for('static', filename='img/introduction-visual.png') }}" alt="Welcome">
                  </div>

                  <form method="POST" action="/demo">
                    <label for="stock-name">Stocks:</label>
                        <input type="text" id="stock-search" placeholder="Search stocks">
                        <div id="stock-checkboxes">

                                <label>
                                    <input type="checkbox" name="stock-name" value="MSFT">
                                    Microsoft
                                </label>
                                <label>
                                    <input type="checkbox" name="stock-name" value="JNJ">
                                    Johnson & Johnson
                                </label>
                                <label>
                                    <input type="checkbox" name="stock-name" value="INTC">
                                    Intel Corporation
                                </label>
                                <label>
                                    <input type="checkbox" name="stock-name" value="BA">
                                    Boeing Co
                                </label>
                                <label>
                                    <input type="checkbox" name="stock-name" value="UNH">
                                    UnitedHealth Group Inc
                                </label>
                                <label>
                                    <input type="checkbox" name="stock-name" value="JPM">
                                    JPMorgan Chase & Co
                                </label>
                                <label>
                                    <input type="checkbox" name="stock-name" value="V">
                                    Visa Inc
                                </label>
                                <label>
                                    <input type="checkbox" name="stock-name" value="PG">
                                    Procter & Gamble Co
                                </label>
                                <label>
                                    <input type="checkbox" name="stock-name" value="HD">
                                    Home Depot Inc
                                </label>
                                <label>
                                    <input type="checkbox" name="stock-name" value="CVX">
                                    Chevron Corp
                                </label>
                                <label>
                                    <input type="checkbox" name="stock-name" value="MRK">
                                    Merck & Co Inc
                                </label>
                                <label>
                                    <input type="checkbox" name="stock-name" value="KO">
                                    Coca-Cola Co
                                </label>
                                <label>
                                    <input type="checkbox" name="stock-name" value="CSCO">
                                    Cisco Systems Inc
                                </label>
                                <label>
                                    <input type="checkbox" name="stock-name" value="MCD">
                                    McDonald's Corp
                                </label>
                                <label>
                                    <input type="checkbox" name="stock-name" value="WMT">
                                    Walmart Inc
                                </label>
                                <label>
                                    <input type="checkbox" name="stock-name" value="CRM">
                                    Salesforce.com Inc
                                </label>
                                <label>
                                    <input type="checkbox" name="stock-name" value="DIS">
                                    The Walt Disney Co
                                </label>
                                <label>
                                    <input type="checkbox" name="stock-name" value="VZ">
                                    Verizon Communications Inc
                                </label>
                                <label>
                                    <input type="checkbox" name="stock-name" value="NKE">
                                    Nike Inc
                                </label>
                                <label>
                                    <input type="checkbox" name="stock-name" value="AAPL">
                                    Apple Inc
                                </label>
                                <label>
                                    <input type="checkbox" name="stock-name" value="IBM">
                                    International Business Machines Corp
                                </label>
                                <label>
                                    <input type="checkbox" name="stock-name" value="GS">
                                    Goldman Sachs Group Inc
                                </label>
                                <label>
                                    <input type="checkbox" name="stock-name" value="HON">
                                    Honeywell International Inc
                                </label>
                                <label>
                                    <input type="checkbox" name="stock-name" value="AXP">
                                    American Express Co
                                </label>
                                <label>
                                    <input type="checkbox" name="stock-name" value="AMGN">
                                    Amgen, Inc.
                                </label>

                                <!-- <button class="cta">Predict
                                    <svg version="1.1" id="Layer_1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px" viewBox="0 0 150 118" style="enable-background:new 0 0 150 118;" xml:space="preserve">
                                    <g transform="translate(0.000000,118.000000) scale(0.100000,-0.100000)">
                                    <path d="M870,1167c-34-17-55-57-46-90c3-15,81-100,194-211l187-185l-565-1c-431,0-571-3-590-13c-55-28-64-94-18-137c21-20,33-20,597-20h575l-192-193C800,103,794,94,849,39c20-20,39-29,61-29c28,0,63,30,298,262c147,144,272,271,279,282c30,51,23,60-219,304C947,1180,926,1196,870,1167z"/>
                                    </g>
                                    </svg>
                                    <span class="btn-background"></span>
                                </button> -->
                            </div>


                            <label for="time-name" style="margin-bottom: 0px;">Time range predictions:</label>
                            <!-- <input type="text" id="source-search" placeholder="Select the source"> -->
                            <div id="time-checkboxes" style="margin-top: 0px; margin-bottom: 10px;">

                                    <label>
                                        <input type="radio" name="time-name" value="3">
                                        3 Months
                                    </label>
                                    <label>
                                        <input type="radio" name="time-name" value="6">
                                        6 Months
                                    </label>


                                    <!-- <button class="cta">Predict
                                        <svg version="1.1" id="Layer_1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px" viewBox="0 0 150 118" style="enable-background:new 0 0 150 118;" xml:space="preserve">
                                        <g transform="translate(0.000000,118.000000) scale(0.100000,-0.100000)">
                                        <path d="M870,1167c-34-17-55-57-46-90c3-15,81-100,194-211l187-185l-565-1c-431,0-571-3-590-13c-55-28-64-94-18-137c21-20,33-20,597-20h575l-192-193C800,103,794,94,849,39c20-20,39-29,61-29c28,0,63,30,298,262c147,144,272,271,279,282c30,51,23,60-219,304C947,1180,926,1196,870,1167z"/>
                                        </g>
                                        </svg>
                                        <span class="btn-background"></span>
                                    </button> -->
                                </div>

                                <!-- <label for="model-name" style="margin-bottom: 10px;">Models:</label>
                                <div id="model-checkboxes" style="margin-top: 0px; margin-bottom: 10px;">

                                        <label>
                                            <input type="checkbox" name="model-name" value="Model 1">
                                            Model 1
                                        </label>
                                        <label>
                                            <input type="checkbox" name="model-name" value="Model 2">
                                            Model 2
                                        </label>
                                        <label>
                                            <input type="checkbox" name="model-name" value="Model 3">
                                            Model 3
                                        </label>
                                        <label>
                                            <input type="checkbox" name="model-name" value="Model 4">
                                            Model 4
                                        </label> -->


                                        <!-- <button class="cta">Predict
                                            <svg version="1.1" id="Layer_1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px" viewBox="0 0 150 118" style="enable-background:new 0 0 150 118;" xml:space="preserve">
                                            <g transform="translate(0.000000,118.000000) scale(0.100000,-0.100000)">
                                            <path d="M870,1167c-34-17-55-57-46-90c3-15,81-100,194-211l187-185l-565-1c-431,0-571-3-590-13c-55-28-64-94-18-137c21-20,33-20,597-20h575l-192-193C800,103,794,94,849,39c20-20,39-29,61-29c28,0,63,30,298,262c147,144,272,271,279,282c30,51,23,60-219,304C947,1180,926,1196,870,1167z"/>
                                            </g>
                                            </svg>
                                            <span class="btn-background"></span>
                                        </button> -->
                                    <!-- </div> -->
                                   <div>
                                    <label for="model-name-toggle" style="margin-bottom: 10px;">Models:</label>
                                </div>
                                    <label class="switch">
                                        <input type="checkbox" id="model-name-toggle" name="model-name-toggle">
                                        <span class="slider"></span>
                                    </label>
                                    <div id="model-bars" style="margin-top: 0px; margin-bottom: 20px; display: none;">
                                        <label for="model-1">Number of LSTM Layers:</label>
                                        <input type="range" id="model-1" name="model-1" min="2" max="100" value="6">
                                        <span id="model-1-value">6</span><br>

                                        <label for="model-2">Learning Rate:</label>
                                        <input type="range" id="model-2" name="model-2" min="0.001" max="0.1" value="0.01" step="0.001">
                                        <span id="model-2-value">0.01</span><br>

                                        <label for="model-3">Early Stopping:</label>
                                        <input type="range" id="model-3" name="model-3" min="10" max="500" value="200">
                                        <span id="model-3-value">200</span><br>

                                        <label for="model-4">Number of Epochs:</label>
                                        <input type="range" id="model-4" name="model-4" min="500" max="5000" value="2000">
                                        <span id="model-4-value">2000</span><br>
                                    </div>


                                    <script>
                                        var toggle = document.getElementById("model-name-toggle");
                                        var checkboxes = document.getElementById("model-bars");
                                        toggle.addEventListener("change", function() {
                                            if (toggle.checked) {
                                                checkboxes.style.display = "block";
                                            } else {
                                                checkboxes.style.display = "none";
                                            }
                                        });


                                        const model1Range = document.getElementById('model-1');
                                        const model1Value = document.getElementById('model-1-value');

                                        model1Range.addEventListener('input', function() {
                                        model1Value.textContent = model1Range.value;
                                        });

                                        const model2Range = document.getElementById('model-2');
                                        const model2Value = document.getElementById('model-2-value');

                                        model2Range.addEventListener('input', function() {
                                        model2Value.textContent = model2Range.value;
                                        });

                                        const model3Range = document.getElementById('model-3');
                                        const model3Value = document.getElementById('model-3-value');

                                        model3Range.addEventListener('input', function() {
                                        model3Value.textContent = model3Range.value;
                                        });

                                        const model4Range = document.getElementById('model-4');
                                        const model4Value = document.getElementById('model-4-value');

                                        model4Range.addEventListener('input', function() {
                                        model4Value.textContent = model4Range.value;
                                        });

                                        const stockCheckboxes = document.querySelectorAll('#stock-checkboxes label');
                                        const stockSearch = document.querySelector('#stock-search');

                                        stockSearch.addEventListener('input', () => {
                                        const searchText = stockSearch.value.toLowerCase();
                                        stockCheckboxes.forEach((checkbox) => {
                                            const stockName = checkbox.textContent.trim().toLowerCase();
                                            checkbox.style.display = stockName.includes(searchText) ? 'block' : 'none';
                                        });
                                        });



                                    </script>

                                    <style>

                                    .switch {
                                        position: relative;
                                        display: inline-block;
                                        width: 60px;
                                        height: 34px;
                                        margin-right: 10px;
                                        margin-top: 10px;
                                        margin-bottom: 10px;
                                      }

                                      .switch input {
                                        opacity: 0;
                                        width: 0;
                                        height: 0;
                                      }

                                      .slider {
                                        position: absolute;
                                        cursor: pointer;
                                        top: 0;
                                        left: 0;
                                        right: 0;
                                        bottom: 0;
                                        background-color: #ccc;
                                        -webkit-transition: .4s;
                                        transition: .4s;
                                        border-radius: 34px;
                                      }

                                      .slider:before {
                                        position: absolute;
                                        content: "";
                                        height: 26px;
                                        width: 26px;
                                        left: 4px;
                                        bottom: 4px;
                                        background-color: white;
                                        -webkit-transition: .4s;
                                        transition: .4s;
                                        border-radius: 50%;
                                      }

                                      input:checked + .slider {
                                        background-color: #2196F3;
                                      }

                                      input:focus + .slider {
                                        box-shadow: 0 0 1px #2196F3;
                                      }

                                      input:checked + .slider:before {
                                        -webkit-transform: translateX(26px);
                                        -ms-transform: translateX(26px);
                                        transform: translateX(26px);
                                      }

                                      .slider.round {
                                        border-radius: 34px;
                                      }

                                      .slider.round:before {
                                        border-radius: 50%;
                                      }

                                      .switch-text {
                                        display: inline-block;
                                        vertical-align: middle;
                                      }
                                      #more-models {
                                        display: none;
                                      }

                                      input:checked ~ #more-models {
                                        display: block;
                                      }
                                    </style>

                            <style>
                                #stock-checkboxes {
                                    overflow-x: auto;
                                    white-space: nowrap;
                                    margin-top: 10px;
                                    margin-bottom: 10px;
                                    border: 1px solid #ccc;
                                    padding: 10px;
                                    max-height: 150px;
                                    overflow-y: auto;
                                }

                                #stock-search {
                                    background-color: black;
                                    color: #f2f2f2;
                                    border: 1px solid #ccc;
                                    border-radius: 4px;
                                    width: 100%;
                                    padding: 5px;
                                    box-sizing: border-box;
                                    margin-bottom: 10px;
                                }

                                #search-stock {
                                    background-color: #f2f2f2;
                                    color: black;
                                    border: 1px solid #ccc;
                                    border-radius: 4px;
                                    width: 100%;
                                    padding: 5px;
                                    box-sizing: border-box;
                                    margin-bottom: 10px;
                                }
                            </style>



                            <!-- <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script> -->
                            <!-- <script>
                                $(document).ready(function() {
                                    // Initialize search
                                    // $('#stock-search').on('keyup', function() {
                                    // var value = $(this).val().toLowerCase();
                                    // $('#stock-checkboxes label').filter(function() {
                                    //     $(this).toggle($(this).text().toLowerCase().indexOf(value) > -1)
                                    // });

                                    $('#source-search').on('keyup', function() {
                                    var value = $(this).val().toLowerCase();
                                    $('#source-checkboxes label').filter(function() {
                                        $(this).toggle($(this).text().toLowerCase().indexOf(value) > -1)
                                    });

                                    $('#model-search').on('keyup', function() {
                                    var value = $(this).val().toLowerCase();
                                    $('#model-checkboxes label').filter(function() {
                                        $(this).toggle($(this).text().toLowerCase().indexOf(value) > -1)
                                    });
                                    });

                                    // Initialize checkboxes
                                    $('#stock-checkboxes input[type=checkbox]').change(function() {
                                    var selected = $('#stock-checkboxes input[type=checkbox]:checked');
                                    var values = $.map(selected, function(checkbox) {
                                        return $(checkbox).val();
                                    });
                                    console.log(values);
                                    });

                                    $('#source-checkboxes input[type=checkbox]').change(function() {
                                    var selected = $('#source-checkboxes input[type=checkbox]:checked');
                                    var values = $.map(selected, function(checkbox) {
                                        return $(checkbox).val();
                                    });
                                    console.log(values);
                                    });

                                    $('#model-checkboxes input[type=checkbox]').change(function() {
                                    var selected = $('#model-checkboxes input[type=checkbox]:checked');
                                    var values = $.map(selected, function(checkbox) {
                                        return $(checkbox).val();
                                    });
                                    console.log(values);
                                    });
                                });
                            </script> -->

                            <button class="cta" id="search-stock" name="search-stock" style="width:100%">Search

                            </button>








                    </div>
                  </form>

                </li>

            <!-- <script>
                const applymtch = document.getElementById("search-stock");

                applymtch.addEventListener("click", () => {
                    const name = Array.from(document.getElementById("stock-name").selectedOptions).map(option => option.value);
                    const source = Array.from(document.getElementById("source-name").selectedOptions).map(option => option.value);
                    const model = Array.from(document.getElementById("model-name").selectedOptions).map(option => option.value);

                    const matches = { name, source, model };

                    localStorage.setItem("matches", JSON.stringify(matches));
                });

                // Retrieve the selections on page load
                const matches = JSON.parse(localStorage.getItem("matches"));
                if (matches) {
                    matches.category.forEach(value => document.querySelector(`#stock-name option[value='${value}']`).selected = true);
                    matches.category.forEach(value => document.querySelector(`#source-name option[value='${value}']`).selected = true);
                    matches.category.forEach(value => document.querySelector(`#model-name option[value='${value}']`).selected = true);
                }
            </script> -->




              <li class="l-section section">
                <div class="work">
                  <h2>Selected work</h2>
                  <div class="work--lockup">
                    <ul class="slider">
    """
    for ticker in tickers:
        predictions_html += f"""
         <li class="slider--item slider--item-left">
                            <a href="#0">
                              <div class="slider--item-image">
                                <img src="{{ url_for('static', filename='img/{str(ticker)}.png') }}" alt="Victory">
                              </div>
                              <p class="slider--item-title">{str(ticker)}</p>
                            </a>
                          </li>    
                          
    """
                      
    predictions_html += """
                    </ul>

                    <div class="slider--prev">
                      <svg version="1.1" id="Layer_1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px"
                      viewBox="0 0 150 118" style="enable-background:new 0 0 150 118;" xml:space="preserve">
                      <g transform="translate(0.000000,118.000000) scale(0.100000,-0.100000)">
                        <path d="M561,1169C525,1155,10,640,3,612c-3-13,1-36,8-52c8-15,134-145,281-289C527,41,562,10,590,10c22,0,41,9,61,29
                        c55,55,49,64-163,278L296,510h575c564,0,576,0,597,20c46,43,37,109-18,137c-19,10-159,13-590,13l-565,1l182,180
                        c101,99,187,188,193,199c16,30,12,57-12,84C631,1174,595,1183,561,1169z"/>
                      </g>
                      </svg>
                    </div>

                    <div class="slider--next">
                      <svg version="1.1" id="Layer_1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px" viewBox="0 0 150 118" style="enable-background:new 0 0 150 118;" xml:space="preserve">
                      <g transform="translate(0.000000,118.000000) scale(0.100000,-0.100000)">
                        <path d="M870,1167c-34-17-55-57-46-90c3-15,81-100,194-211l187-185l-565-1c-431,0-571-3-590-13c-55-28-64-94-18-137c21-20,33-20,597-20h575l-192-193C800,103,794,94,849,39c20-20,39-29,61-29c28,0,63,30,298,262c147,144,272,271,279,282c30,51,23,60-219,304C947,1180,926,1196,870,1167z"/>
                      </g>
                      </svg>
                    </div>
                  </div>
                </div>
              </li>
            </ul>
          </div>
        </div>
      </div>
      <ul class="outer-nav">
        <li class="is-active">Home</li>
        <li >Predictions</li>
      </ul>
    </div>

    <script src="https://ajax.googleapis.com/ajax/libs/jquery/2.2.4/jquery.min.js"></script>
    <script>window.jQuery || document.write("<script src='{{ url_for('static', filename='js/vendor/jquery-2.2.4.min.js') }}'><\/script>")</script>
    <script src="{{ url_for('static', filename='js/functions-min.js') }}"></script>
    </body>
    </html>
    """
    return predictions_html

# %%
app = Flask("Stock Predictions", static_folder='static')
app.config['TEMPLATES_AUTO_RELOAD'] = True
        
@app.route('/')
def index():
    return render_template('index.html')

@app.route('/predictions')
def predictions():
    return render_template('predictions.html')

@app.route('/demo', methods=['GET', 'POST'])
def demo():
    if request.method == 'POST':
        tickers = request.form.getlist('stock-name')
        time = int(request.form.get('time-name'))
        toggle = request.form.get('model-name-toggle')
        layers = int(request.form.get('model-1'))
        lr = float(request.form.get('model-2'))
        early_stopping = int(request.form.get('model-3'))
        epochs = int(request.form.get('model-4'))
        
        display(f"Selected stocks: {tickers}")
        display(f"Selected time range: {time}")
        display(f"Custom model: {toggle}")

        if toggle is None:
            for ticker in tickers:
                # Still need to define time in lstm.py
                lstm = Lstm(ticker, time)
                lstm.predict()
                lstm.plot_preds()
        else:
            for ticker in tickers:
                lstm = Lstm(ticker, time)
                lstm.train_lstm(layers=layers, 
                                lr=lr, 
                                early_stopping=early_stopping, 
                                epochs=epochs,
                                save='Off')
                lstm.predict()
                lstm.plot_preds()

        
        if toggle is None:
            pass
        else:
            display(f"Number of LSTM layers: {layers}")
            display(f"Learning rate: {lr}")
            display(f"Early Stopping: {early_stopping}")
            display(f"Number of Epochs: {epochs}")

        #predictions_html_new = render_template(predictions_html)
        #return render_template('predictions.html')
        f = open('templates/predictions.html', 'w')
        f.write(Markup(render_predictions(tickers)))
        f.flush()
        f.close()
        print("overwritten")
        return redirect(url_for('predictions'))
    else:
        return render_template('demo.html')


if __name__ == '__main__':
    app.run(host='localhost', port=5001)
# Out:
#  * Serving Flask app 'Stock Predictions'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://localhost:5001
# Press CTRL+C to quit
# 127.0.0.1 - - [14/May/2023 00:00:25] "GET /demo HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2023 00:00:25] "GET /static/css/main.css HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:00:25] "GET /static/img/logo.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:00:25] "GET /static/js/functions-min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:00:25] "GET /static/img/introduction-visual.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:00:25] "GET /static/css/fonts/Montserrat-Regular.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:00:25] "GET /static/css/fonts/Montserrat-Bold.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:00:25] "GET /static/css/fonts/Montserrat-Light.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:00:25] "GET /static/css/fonts/Montserrat-Black.woff HTTP/1.1" 304 -
# "Selected stocks: ['AAPL']"
# 'Selected time range: 6'
# 'Custom model: on'
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# lstm intance initialized
# AAPL data imported. Size: (1253, 34)
# AAPL size: (1253, 34)
# Epoch 1/500
# 22/22 [==============================] - 1s 12ms/step - loss: 99.6653 - mae: 99.6653 - val_loss: 63.3929 - val_mae: 63.3929
# Epoch 2/500
# 22/22 [==============================] - 0s 2ms/step - loss: 22.4645 - mae: 22.4645 - val_loss: 24.4494 - val_mae: 24.4494
# Epoch 3/500
# 22/22 [==============================] - 0s 3ms/step - loss: 15.7385 - mae: 15.7385 - val_loss: 21.5363 - val_mae: 21.5363
# Epoch 4/500
# 22/22 [==============================] - 0s 3ms/step - loss: 12.5869 - mae: 12.5869 - val_loss: 60.1772 - val_mae: 60.1772
# Epoch 5/500
# 22/22 [==============================] - 0s 2ms/step - loss: 16.3276 - mae: 16.3276 - val_loss: 49.6253 - val_mae: 49.6253
# Epoch 6/500
# 22/22 [==============================] - 0s 2ms/step - loss: 9.9513 - mae: 9.9513 - val_loss: 65.7948 - val_mae: 65.7948
# Epoch 7/500
# 22/22 [==============================] - 0s 2ms/step - loss: 7.1720 - mae: 7.1720 - val_loss: 66.0868 - val_mae: 66.0868
# Epoch 8/500
# 22/22 [==============================] - 0s 2ms/step - loss: 9.7383 - mae: 9.7383 - val_loss: 72.5290 - val_mae: 72.5290
# Epoch 9/500
# 22/22 [==============================] - 0s 2ms/step - loss: 11.3812 - mae: 11.3812 - val_loss: 66.1790 - val_mae: 66.1790
# Epoch 10/500
# 22/22 [==============================] - 0s 2ms/step - loss: 9.8622 - mae: 9.8622 - val_loss: 63.4542 - val_mae: 63.4542
# Epoch 11/500
# 22/22 [==============================] - 0s 3ms/step - loss: 8.2679 - mae: 8.2679 - val_loss: 48.8825 - val_mae: 48.8825
# Epoch 12/500
# 22/22 [==============================] - 0s 2ms/step - loss: 13.2320 - mae: 13.2320 - val_loss: 51.5869 - val_mae: 51.5869
# Epoch 13/500
# 22/22 [==============================] - 0s 2ms/step - loss: 7.8580 - mae: 7.8580 - val_loss: 51.2159 - val_mae: 51.2159
# Epoch 13: early stopping
# 22/22 [==============================] - 0s 711us/step
# 6/6 [==============================] - 0s 793us/step
# 7/7 [==============================] - 0s 716us/step
# MAE:  49.10987628358354
# 6/6 [==============================] - 0s 885us/step
# 'Number of LSTM layers: 3'
# 'Learning rate: 0.1'
# 'Early Stopping: 10'
# 'Number of Epochs: 500'
# 127.0.0.1 - - [14/May/2023 00:00:46] "POST /demo HTTP/1.1" 302 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:00:46] "POST /demo HTTP/1.1" 302 -
# 127.0.0.1 - - [14/May/2023 00:00:46] "GET /predictions HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:00:46] "GET /predictions HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2023 00:00:46] "GET /static/img/introduction-visual.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:00:46] "GET /static/img/introduction-visual.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:00:46] "GET /static/css/main.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:00:46] "GET /static/css/main.css HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:00:46] "GET /static/img/logo.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:00:46] "GET /static/img/logo.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:00:46] "GET /%7B%20url_for('static',%20filename='img/AAPL.png')%20%7D HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:00:46] "GET /%7B%20url_for('static',%20filename='img/AAPL.png')%20%7D HTTP/1.1" 404 -
# 127.0.0.1 - - [14/May/2023 00:00:46] "GET /static/js/functions-min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:00:46] "GET /static/js/functions-min.js HTTP/1.1" 304 -
# overwritten
# 127.0.0.1 - - [14/May/2023 00:02:09] "GET /demo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:02:09] "GET /demo HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2023 00:02:09] "GET /static/css/main.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:02:09] "GET /static/css/main.css HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:02:09] "GET /static/img/logo.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:02:09] "GET /static/img/logo.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:02:09] "GET /static/js/functions-min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:02:09] "GET /static/js/functions-min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:02:09] "GET /static/img/introduction-visual.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:02:09] "GET /static/img/introduction-visual.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:02:09] "GET /static/css/fonts/Montserrat-Regular.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:02:09] "GET /static/css/fonts/Montserrat-Regular.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:02:09] "GET /static/css/fonts/Montserrat-Light.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:02:09] "GET /static/css/fonts/Montserrat-Light.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:02:09] "GET /static/css/fonts/Montserrat-Bold.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:02:09] "GET /static/css/fonts/Montserrat-Bold.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:02:09] "GET /static/css/fonts/Montserrat-Black.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:02:09] "GET /static/css/fonts/Montserrat-Black.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:04:26] "GET /demo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:04:26] "GET /demo HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2023 00:04:26] "GET /static/css/main.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:04:26] "GET /static/css/main.css HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:04:26] "GET /static/img/logo.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:04:26] "GET /static/img/logo.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:04:26] "GET /static/js/functions-min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:04:26] "GET /static/js/functions-min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:04:26] "GET /static/img/introduction-visual.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:04:26] "GET /static/img/introduction-visual.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:04:26] "GET /static/css/fonts/Montserrat-Regular.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:04:26] "GET /static/css/fonts/Montserrat-Regular.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:04:26] "GET /static/css/fonts/Montserrat-Light.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:04:26] "GET /static/css/fonts/Montserrat-Light.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:04:26] "GET /static/css/fonts/Montserrat-Bold.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:04:26] "GET /static/css/fonts/Montserrat-Black.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:04:26] "GET /static/css/fonts/Montserrat-Bold.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:04:26] "GET /static/css/fonts/Montserrat-Black.woff HTTP/1.1" 304 -
# "Selected stocks: ['GOOG']"
# 'Selected time range: 3'
# 'Custom model: None'
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# lstm intance initialized
# GOOG data imported. Size: (1258, 34)
# GOOG size: (1258, 34)
# Epoch 1/2000
# 24/24 [==============================] - 3s 17ms/step - loss: 52.8302 - mae: 52.8302 - val_loss: 11.5520 - val_mae: 11.5520
# Epoch 2/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 12.4810 - mae: 12.4810 - val_loss: 17.2796 - val_mae: 17.2796
# Epoch 3/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 10.1235 - mae: 10.1235 - val_loss: 21.5367 - val_mae: 21.5367
# Epoch 4/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 7.9848 - mae: 7.9848 - val_loss: 20.4528 - val_mae: 20.4528
# Epoch 5/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 6.5189 - mae: 6.5189 - val_loss: 26.6318 - val_mae: 26.6318
# Epoch 6/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 6.1596 - mae: 6.1596 - val_loss: 36.4911 - val_mae: 36.4911
# Epoch 7/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 4.6369 - mae: 4.6369 - val_loss: 19.6847 - val_mae: 19.6847
# Epoch 8/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 4.5370 - mae: 4.5370 - val_loss: 30.1094 - val_mae: 30.1094
# Epoch 9/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 4.0168 - mae: 4.0168 - val_loss: 26.7551 - val_mae: 26.7551
# Epoch 10/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 5.0636 - mae: 5.0636 - val_loss: 17.4855 - val_mae: 17.4855
# Epoch 11/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 4.7095 - mae: 4.7095 - val_loss: 26.4654 - val_mae: 26.4654
# Epoch 12/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 3.4329 - mae: 3.4329 - val_loss: 21.2995 - val_mae: 21.2995
# Epoch 13/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 3.6966 - mae: 3.6966 - val_loss: 28.7005 - val_mae: 28.7005
# Epoch 14/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 4.7561 - mae: 4.7561 - val_loss: 17.1425 - val_mae: 17.1425
# Epoch 15/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 7.8968 - mae: 7.8968 - val_loss: 18.8153 - val_mae: 18.8153
# Epoch 16/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 7.9541 - mae: 7.9541 - val_loss: 34.5214 - val_mae: 34.5214
# Epoch 17/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 5.8999 - mae: 5.8999 - val_loss: 37.9157 - val_mae: 37.9157
# Epoch 18/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 3.6126 - mae: 3.6126 - val_loss: 30.4107 - val_mae: 30.4107
# Epoch 19/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 3.8894 - mae: 3.8894 - val_loss: 25.5102 - val_mae: 25.5102
# Epoch 20/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.9425 - mae: 2.9425 - val_loss: 28.5697 - val_mae: 28.5697
# Epoch 21/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 3.9714 - mae: 3.9714 - val_loss: 19.6130 - val_mae: 19.6130
# Epoch 22/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 5.1213 - mae: 5.1213 - val_loss: 25.5039 - val_mae: 25.5039
# Epoch 23/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 3.1508 - mae: 3.1508 - val_loss: 22.6869 - val_mae: 22.6869
# Epoch 24/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 3.1892 - mae: 3.1892 - val_loss: 23.5189 - val_mae: 23.5189
# Epoch 25/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 3.0916 - mae: 3.0916 - val_loss: 33.5044 - val_mae: 33.5044
# Epoch 26/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.9313 - mae: 2.9313 - val_loss: 27.6327 - val_mae: 27.6327
# Epoch 27/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 3.2142 - mae: 3.2142 - val_loss: 31.1341 - val_mae: 31.1341
# Epoch 28/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 3.7075 - mae: 3.7075 - val_loss: 17.8801 - val_mae: 17.8801
# Epoch 29/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 4.0742 - mae: 4.0742 - val_loss: 27.6499 - val_mae: 27.6499
# Epoch 30/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 3.3011 - mae: 3.3011 - val_loss: 27.2405 - val_mae: 27.2405
# Epoch 31/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 3.0979 - mae: 3.0979 - val_loss: 24.1775 - val_mae: 24.1775
# Epoch 32/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 3.0828 - mae: 3.0828 - val_loss: 19.3814 - val_mae: 19.3814
# Epoch 33/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 3.1303 - mae: 3.1303 - val_loss: 27.8233 - val_mae: 27.8233
# Epoch 34/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.5914 - mae: 2.5914 - val_loss: 24.1477 - val_mae: 24.1477
# Epoch 35/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.7151 - mae: 2.7151 - val_loss: 25.7912 - val_mae: 25.7912
# Epoch 36/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.0557 - mae: 2.0557 - val_loss: 27.2110 - val_mae: 27.2110
# Epoch 37/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.2182 - mae: 2.2182 - val_loss: 18.9836 - val_mae: 18.9836
# Epoch 38/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.9221 - mae: 2.9221 - val_loss: 20.3001 - val_mae: 20.3001
# Epoch 39/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 3.3023 - mae: 3.3023 - val_loss: 26.1288 - val_mae: 26.1288
# Epoch 40/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.3783 - mae: 2.3783 - val_loss: 24.8498 - val_mae: 24.8498
# Epoch 41/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 3.5353 - mae: 3.5353 - val_loss: 29.1735 - val_mae: 29.1735
# Epoch 42/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.8928 - mae: 2.8928 - val_loss: 24.7165 - val_mae: 24.7165
# Epoch 43/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.3989 - mae: 2.3989 - val_loss: 27.0622 - val_mae: 27.0622
# Epoch 44/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 3.5388 - mae: 3.5388 - val_loss: 20.7295 - val_mae: 20.7295
# Epoch 45/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.3697 - mae: 2.3697 - val_loss: 22.7243 - val_mae: 22.7243
# Epoch 46/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 3.4176 - mae: 3.4176 - val_loss: 15.4608 - val_mae: 15.4608
# Epoch 47/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 4.0683 - mae: 4.0683 - val_loss: 23.9420 - val_mae: 23.9420
# Epoch 48/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.0293 - mae: 2.0293 - val_loss: 20.6152 - val_mae: 20.6152
# Epoch 49/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.6551 - mae: 2.6551 - val_loss: 29.0847 - val_mae: 29.0847
# Epoch 50/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 3.0832 - mae: 3.0832 - val_loss: 23.4804 - val_mae: 23.4804
# Epoch 51/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 3.2461 - mae: 3.2461 - val_loss: 24.9604 - val_mae: 24.9604
# Epoch 52/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 3.8920 - mae: 3.8920 - val_loss: 24.9389 - val_mae: 24.9389
# Epoch 53/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 3.3365 - mae: 3.3365 - val_loss: 35.5295 - val_mae: 35.5295
# Epoch 54/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 5.5056 - mae: 5.5056 - val_loss: 15.7972 - val_mae: 15.7972
# Epoch 55/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.3249 - mae: 2.3249 - val_loss: 21.2440 - val_mae: 21.2440
# Epoch 56/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.2648 - mae: 2.2648 - val_loss: 23.0237 - val_mae: 23.0237
# Epoch 57/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.2590 - mae: 2.2590 - val_loss: 22.3074 - val_mae: 22.3074
# Epoch 58/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.1243 - mae: 2.1243 - val_loss: 20.7354 - val_mae: 20.7354
# Epoch 59/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.9332 - mae: 1.9332 - val_loss: 26.1067 - val_mae: 26.1067
# Epoch 60/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 3.4487 - mae: 3.4487 - val_loss: 17.8261 - val_mae: 17.8261
# Epoch 61/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 4.7947 - mae: 4.7947 - val_loss: 22.7548 - val_mae: 22.7548
# Epoch 62/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 3.4135 - mae: 3.4135 - val_loss: 22.9993 - val_mae: 22.9993
# Epoch 63/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.4383 - mae: 2.4383 - val_loss: 19.6947 - val_mae: 19.6947
# Epoch 64/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.1432 - mae: 2.1432 - val_loss: 21.0808 - val_mae: 21.0808
# Epoch 65/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.9588 - mae: 1.9588 - val_loss: 19.6621 - val_mae: 19.6621
# Epoch 66/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.0249 - mae: 2.0249 - val_loss: 20.9540 - val_mae: 20.9540
# Epoch 67/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.1458 - mae: 2.1458 - val_loss: 20.9931 - val_mae: 20.9931
# Epoch 68/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.9948 - mae: 1.9948 - val_loss: 24.0133 - val_mae: 24.0133
# Epoch 69/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.4924 - mae: 2.4924 - val_loss: 27.6261 - val_mae: 27.6261
# Epoch 70/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.6615 - mae: 2.6615 - val_loss: 29.0522 - val_mae: 29.0522
# Epoch 71/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.8946 - mae: 2.8946 - val_loss: 20.1930 - val_mae: 20.1930
# Epoch 72/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.1143 - mae: 2.1143 - val_loss: 18.1549 - val_mae: 18.1549
# Epoch 73/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.5266 - mae: 2.5266 - val_loss: 21.4593 - val_mae: 21.4593
# Epoch 74/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.3488 - mae: 2.3488 - val_loss: 19.6909 - val_mae: 19.6909
# Epoch 75/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.7013 - mae: 2.7013 - val_loss: 25.9717 - val_mae: 25.9717
# Epoch 76/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.9528 - mae: 1.9528 - val_loss: 21.4750 - val_mae: 21.4750
# Epoch 77/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.9164 - mae: 1.9164 - val_loss: 22.7762 - val_mae: 22.7762
# Epoch 78/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.9348 - mae: 1.9348 - val_loss: 19.4697 - val_mae: 19.4697
# Epoch 79/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.7349 - mae: 1.7349 - val_loss: 20.7722 - val_mae: 20.7722
# Epoch 80/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.9052 - mae: 1.9052 - val_loss: 22.9751 - val_mae: 22.9751
# Epoch 81/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.0562 - mae: 2.0562 - val_loss: 22.1997 - val_mae: 22.1997
# Epoch 82/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.0806 - mae: 2.0806 - val_loss: 23.0023 - val_mae: 23.0023
# Epoch 83/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 1.9964 - mae: 1.9964 - val_loss: 18.8946 - val_mae: 18.8946
# Epoch 84/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.2430 - mae: 2.2430 - val_loss: 18.7477 - val_mae: 18.7477
# Epoch 85/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 1.8748 - mae: 1.8748 - val_loss: 22.8031 - val_mae: 22.8031
# Epoch 86/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 1.7560 - mae: 1.7560 - val_loss: 23.8654 - val_mae: 23.8654
# Epoch 87/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.7659 - mae: 1.7659 - val_loss: 20.8763 - val_mae: 20.8763
# Epoch 88/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.5896 - mae: 2.5896 - val_loss: 21.5190 - val_mae: 21.5190
# Epoch 89/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 1.6813 - mae: 1.6813 - val_loss: 23.0160 - val_mae: 23.0160
# Epoch 90/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.2297 - mae: 2.2297 - val_loss: 18.3681 - val_mae: 18.3681
# Epoch 91/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.1855 - mae: 2.1855 - val_loss: 19.2450 - val_mae: 19.2450
# Epoch 92/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.6588 - mae: 1.6588 - val_loss: 22.5808 - val_mae: 22.5808
# Epoch 93/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.2270 - mae: 2.2270 - val_loss: 19.4402 - val_mae: 19.4402
# Epoch 94/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.0426 - mae: 2.0426 - val_loss: 21.1804 - val_mae: 21.1804
# Epoch 95/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.7142 - mae: 1.7142 - val_loss: 23.5186 - val_mae: 23.5186
# Epoch 96/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.6651 - mae: 1.6651 - val_loss: 21.2303 - val_mae: 21.2303
# Epoch 97/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.0777 - mae: 2.0777 - val_loss: 20.3383 - val_mae: 20.3383
# Epoch 98/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.0753 - mae: 2.0753 - val_loss: 23.3588 - val_mae: 23.3588
# Epoch 99/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 1.6669 - mae: 1.6669 - val_loss: 26.2871 - val_mae: 26.2871
# Epoch 100/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.4813 - mae: 2.4813 - val_loss: 17.0142 - val_mae: 17.0142
# Epoch 101/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.3546 - mae: 2.3546 - val_loss: 20.3395 - val_mae: 20.3395
# Epoch 102/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.7872 - mae: 2.7872 - val_loss: 28.5299 - val_mae: 28.5299
# Epoch 103/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.9269 - mae: 2.9269 - val_loss: 18.3543 - val_mae: 18.3543
# Epoch 104/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.8030 - mae: 2.8030 - val_loss: 16.6663 - val_mae: 16.6663
# Epoch 105/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 3.1162 - mae: 3.1162 - val_loss: 22.5847 - val_mae: 22.5847
# Epoch 106/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.4041 - mae: 2.4041 - val_loss: 17.6382 - val_mae: 17.6382
# Epoch 107/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.7565 - mae: 1.7565 - val_loss: 20.9801 - val_mae: 20.9801
# Epoch 108/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.4165 - mae: 2.4165 - val_loss: 15.9802 - val_mae: 15.9802
# Epoch 109/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.9376 - mae: 2.9376 - val_loss: 25.5252 - val_mae: 25.5252
# Epoch 110/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.6285 - mae: 2.6285 - val_loss: 16.5828 - val_mae: 16.5828
# Epoch 111/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.1624 - mae: 2.1624 - val_loss: 22.2499 - val_mae: 22.2499
# Epoch 112/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.8557 - mae: 1.8557 - val_loss: 18.3462 - val_mae: 18.3462
# Epoch 113/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.6537 - mae: 1.6537 - val_loss: 19.6059 - val_mae: 19.6059
# Epoch 114/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.2792 - mae: 2.2792 - val_loss: 17.2179 - val_mae: 17.2179
# Epoch 115/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.5136 - mae: 2.5136 - val_loss: 15.5781 - val_mae: 15.5781
# Epoch 116/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 3.1135 - mae: 3.1135 - val_loss: 24.0868 - val_mae: 24.0868
# Epoch 117/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.0314 - mae: 2.0314 - val_loss: 18.1763 - val_mae: 18.1763
# Epoch 118/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 3.2137 - mae: 3.2137 - val_loss: 19.3247 - val_mae: 19.3247
# Epoch 119/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.9248 - mae: 1.9248 - val_loss: 19.4518 - val_mae: 19.4518
# Epoch 120/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.0540 - mae: 2.0540 - val_loss: 19.3470 - val_mae: 19.3470
# Epoch 121/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.8727 - mae: 1.8727 - val_loss: 26.0135 - val_mae: 26.0135
# Epoch 122/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.2571 - mae: 2.2571 - val_loss: 20.0327 - val_mae: 20.0327
# Epoch 123/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 1.9389 - mae: 1.9389 - val_loss: 19.6096 - val_mae: 19.6096
# Epoch 124/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 1.7802 - mae: 1.7802 - val_loss: 16.7733 - val_mae: 16.7733
# Epoch 125/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.7111 - mae: 2.7111 - val_loss: 18.3590 - val_mae: 18.3590
# Epoch 126/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.6169 - mae: 1.6169 - val_loss: 21.5938 - val_mae: 21.5938
# Epoch 127/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.5287 - mae: 1.5287 - val_loss: 18.8759 - val_mae: 18.8759
# Epoch 128/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.1007 - mae: 2.1007 - val_loss: 23.6626 - val_mae: 23.6626
# Epoch 129/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.8782 - mae: 1.8782 - val_loss: 21.3999 - val_mae: 21.3999
# Epoch 130/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.7802 - mae: 1.7802 - val_loss: 17.8885 - val_mae: 17.8885
# Epoch 131/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.0942 - mae: 2.0942 - val_loss: 22.5670 - val_mae: 22.5670
# Epoch 132/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 1.9239 - mae: 1.9239 - val_loss: 19.1017 - val_mae: 19.1017
# Epoch 133/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 1.9556 - mae: 1.9556 - val_loss: 21.9970 - val_mae: 21.9970
# Epoch 134/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.0064 - mae: 2.0064 - val_loss: 20.8943 - val_mae: 20.8943
# Epoch 135/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.3853 - mae: 1.3853 - val_loss: 19.5997 - val_mae: 19.5997
# Epoch 136/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.6943 - mae: 1.6943 - val_loss: 23.1757 - val_mae: 23.1757
# Epoch 137/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.4834 - mae: 1.4834 - val_loss: 22.5254 - val_mae: 22.5254
# Epoch 138/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.2796 - mae: 2.2796 - val_loss: 17.8351 - val_mae: 17.8351
# Epoch 139/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.6627 - mae: 2.6627 - val_loss: 17.8226 - val_mae: 17.8226
# Epoch 140/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.0311 - mae: 2.0311 - val_loss: 18.1984 - val_mae: 18.1984
# Epoch 141/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 1.8631 - mae: 1.8631 - val_loss: 19.2304 - val_mae: 19.2304
# Epoch 142/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 1.7087 - mae: 1.7087 - val_loss: 20.0376 - val_mae: 20.0376
# Epoch 143/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 1.8484 - mae: 1.8484 - val_loss: 17.7995 - val_mae: 17.7995
# Epoch 144/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 1.9050 - mae: 1.9050 - val_loss: 18.6991 - val_mae: 18.6991
# Epoch 145/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 1.7428 - mae: 1.7428 - val_loss: 22.3496 - val_mae: 22.3496
# Epoch 146/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.8455 - mae: 1.8455 - val_loss: 19.8073 - val_mae: 19.8073
# Epoch 147/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.6590 - mae: 1.6590 - val_loss: 17.2196 - val_mae: 17.2196
# Epoch 148/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.4922 - mae: 1.4922 - val_loss: 19.7813 - val_mae: 19.7813
# Epoch 149/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.8632 - mae: 1.8632 - val_loss: 18.6024 - val_mae: 18.6024
# Epoch 150/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.5472 - mae: 1.5472 - val_loss: 17.9851 - val_mae: 17.9851
# Epoch 151/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.7953 - mae: 1.7953 - val_loss: 20.3051 - val_mae: 20.3051
# Epoch 152/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 1.7670 - mae: 1.7670 - val_loss: 16.9231 - val_mae: 16.9231
# Epoch 153/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.0001 - mae: 2.0001 - val_loss: 18.4897 - val_mae: 18.4897
# Epoch 154/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.2943 - mae: 2.2943 - val_loss: 18.3694 - val_mae: 18.3694
# Epoch 155/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 1.9228 - mae: 1.9228 - val_loss: 19.2947 - val_mae: 19.2947
# Epoch 156/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 1.5997 - mae: 1.5997 - val_loss: 16.9559 - val_mae: 16.9559
# Epoch 157/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.4639 - mae: 2.4639 - val_loss: 19.2191 - val_mae: 19.2191
# Epoch 158/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 1.7748 - mae: 1.7748 - val_loss: 24.4173 - val_mae: 24.4173
# Epoch 159/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.0871 - mae: 2.0871 - val_loss: 22.7628 - val_mae: 22.7628
# Epoch 160/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 1.9385 - mae: 1.9385 - val_loss: 15.9735 - val_mae: 15.9735
# Epoch 161/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.4685 - mae: 2.4685 - val_loss: 18.4955 - val_mae: 18.4955
# Epoch 162/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 1.9712 - mae: 1.9712 - val_loss: 21.6894 - val_mae: 21.6894
# Epoch 163/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 1.9059 - mae: 1.9059 - val_loss: 19.9512 - val_mae: 19.9512
# Epoch 164/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 1.4873 - mae: 1.4873 - val_loss: 18.4153 - val_mae: 18.4153
# Epoch 165/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 1.6077 - mae: 1.6077 - val_loss: 21.1308 - val_mae: 21.1308
# Epoch 166/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 3.1235 - mae: 3.1235 - val_loss: 17.9250 - val_mae: 17.9250
# Epoch 167/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.7406 - mae: 1.7406 - val_loss: 19.3307 - val_mae: 19.3307
# Epoch 168/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.6776 - mae: 1.6776 - val_loss: 17.6704 - val_mae: 17.6704
# Epoch 169/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.9924 - mae: 1.9924 - val_loss: 24.4813 - val_mae: 24.4813
# Epoch 170/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 3.0291 - mae: 3.0291 - val_loss: 22.4071 - val_mae: 22.4071
# Epoch 171/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.5252 - mae: 2.5252 - val_loss: 19.0114 - val_mae: 19.0114
# Epoch 172/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.0039 - mae: 2.0039 - val_loss: 19.2176 - val_mae: 19.2176
# Epoch 173/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.3253 - mae: 2.3253 - val_loss: 17.3832 - val_mae: 17.3832
# Epoch 174/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.6089 - mae: 2.6089 - val_loss: 17.1739 - val_mae: 17.1739
# Epoch 175/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 1.9762 - mae: 1.9762 - val_loss: 18.2495 - val_mae: 18.2495
# Epoch 176/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.1809 - mae: 2.1809 - val_loss: 21.4612 - val_mae: 21.4612
# Epoch 177/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.5082 - mae: 1.5082 - val_loss: 17.8014 - val_mae: 17.8014
# Epoch 178/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.9799 - mae: 1.9799 - val_loss: 20.6854 - val_mae: 20.6854
# Epoch 179/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.4903 - mae: 1.4903 - val_loss: 21.1201 - val_mae: 21.1201
# Epoch 180/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.5100 - mae: 1.5100 - val_loss: 16.5020 - val_mae: 16.5020
# Epoch 181/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.7350 - mae: 1.7350 - val_loss: 18.1200 - val_mae: 18.1200
# Epoch 182/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.2516 - mae: 2.2516 - val_loss: 23.9595 - val_mae: 23.9595
# Epoch 183/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 3.4059 - mae: 3.4059 - val_loss: 22.8102 - val_mae: 22.8102
# Epoch 184/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.4893 - mae: 2.4893 - val_loss: 20.0270 - val_mae: 20.0270
# Epoch 185/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 1.7280 - mae: 1.7280 - val_loss: 17.6864 - val_mae: 17.6864
# Epoch 186/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.6879 - mae: 2.6879 - val_loss: 25.6720 - val_mae: 25.6720
# Epoch 187/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 2.1572 - mae: 2.1572 - val_loss: 25.0707 - val_mae: 25.0707
# Epoch 188/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.7892 - mae: 2.7892 - val_loss: 17.1214 - val_mae: 17.1214
# Epoch 189/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 1.7329 - mae: 1.7329 - val_loss: 20.8506 - val_mae: 20.8506
# Epoch 190/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 1.8602 - mae: 1.8602 - val_loss: 19.3266 - val_mae: 19.3266
# Epoch 191/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 1.7389 - mae: 1.7389 - val_loss: 19.0042 - val_mae: 19.0042
# Epoch 192/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 1.6833 - mae: 1.6833 - val_loss: 18.9048 - val_mae: 18.9048
# Epoch 193/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 1.3711 - mae: 1.3711 - val_loss: 17.0040 - val_mae: 17.0040
# Epoch 194/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.8912 - mae: 1.8912 - val_loss: 17.5504 - val_mae: 17.5504
# Epoch 195/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.5035 - mae: 1.5035 - val_loss: 19.6436 - val_mae: 19.6436
# Epoch 196/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 1.3949 - mae: 1.3949 - val_loss: 17.7268 - val_mae: 17.7268
# Epoch 197/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.0355 - mae: 2.0355 - val_loss: 18.0732 - val_mae: 18.0732
# Epoch 198/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.4792 - mae: 2.4792 - val_loss: 21.6428 - val_mae: 21.6428
# Epoch 199/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 2.7056 - mae: 2.7056 - val_loss: 17.7912 - val_mae: 17.7912
# Epoch 200/2000
# 24/24 [==============================] - 0s 5ms/step - loss: 1.3903 - mae: 1.3903 - val_loss: 19.0121 - val_mae: 19.0121
# Epoch 201/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 1.7263 - mae: 1.7263 - val_loss: 20.6261 - val_mae: 20.6261
# Epoch 201: early stopping
# 24/24 [==============================] - 0s 995us/step
# 6/6 [==============================] - 0s 1ms/step
# 8/8 [==============================] - 0s 1ms/step
# MAE:  24.83899742817675
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 3/3 [==============================] - 0s 1ms/step
# 127.0.0.1 - - [14/May/2023 00:05:01] "POST /demo HTTP/1.1" 302 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:05:01] "POST /demo HTTP/1.1" 302 -
# 127.0.0.1 - - [14/May/2023 00:05:01] "GET /predictions HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:05:01] "GET /predictions HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2023 00:05:01] "GET /static/css/main.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:05:01] "GET /static/css/main.css HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:05:01] "GET /static/img/logo.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:05:01] "GET /static/img/logo.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:05:01] "GET /static/js/functions-min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:05:01] "GET /static/js/functions-min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:05:01] "GET /static/img/introduction-visual.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:05:01] "GET /static/img/introduction-visual.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:05:01] "GET /%7B%20url_for('static',%20filename='img/GOOG.png')%20%7D HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:05:01] "GET /%7B%20url_for('static',%20filename='img/GOOG.png')%20%7D HTTP/1.1" 404 -
# 127.0.0.1 - - [14/May/2023 00:05:01] "GET /static/css/fonts/Montserrat-Regular.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:05:01] "GET /static/css/fonts/Montserrat-Regular.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:05:01] "GET /static/css/fonts/Montserrat-Bold.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:05:01] "GET /static/css/fonts/Montserrat-Bold.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:05:01] "GET /static/css/fonts/Montserrat-Light.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:05:01] "GET /static/css/fonts/Montserrat-Light.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:05:01] "GET /static/css/fonts/Montserrat-Black.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:05:01] "GET /static/css/fonts/Montserrat-Black.woff HTTP/1.1" 304 -
# overwritten
# 127.0.0.1 - - [14/May/2023 00:06:54] "GET /demo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:06:54] "GET /demo HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2023 00:06:54] "GET /static/css/main.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:06:54] "GET /static/css/main.css HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:06:54] "GET /static/img/logo.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:06:54] "GET /static/img/logo.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:06:55] "GET /static/img/introduction-visual.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:06:55] "GET /static/img/introduction-visual.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:06:55] "GET /static/js/functions-min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:06:55] "GET /static/js/functions-min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:06:55] "GET /static/css/fonts/Montserrat-Regular.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:06:55] "GET /static/css/fonts/Montserrat-Regular.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:06:55] "GET /static/css/fonts/Montserrat-Bold.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:06:55] "GET /static/css/fonts/Montserrat-Bold.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:06:55] "GET /static/css/fonts/Montserrat-Light.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:06:55] "GET /static/css/fonts/Montserrat-Light.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:06:55] "GET /static/css/fonts/Montserrat-Black.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:06:55] "GET /static/css/fonts/Montserrat-Black.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:07:28] "GET /demo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:07:28] "GET /demo HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2023 00:07:28] "GET /static/css/main.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:07:28] "GET /static/css/main.css HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:07:28] "GET /static/img/logo.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:07:28] "GET /static/img/logo.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:07:28] "GET /static/js/functions-min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:07:28] "GET /static/js/functions-min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:07:28] "GET /static/img/introduction-visual.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:07:28] "GET /static/img/introduction-visual.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:07:28] "GET /static/css/fonts/Montserrat-Regular.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:07:28] "GET /static/css/fonts/Montserrat-Bold.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:07:28] "GET /static/css/fonts/Montserrat-Regular.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:07:28] "GET /static/css/fonts/Montserrat-Light.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:07:28] "GET /static/css/fonts/Montserrat-Bold.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:07:28] "GET /static/css/fonts/Montserrat-Black.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:07:28] "GET /static/css/fonts/Montserrat-Light.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:07:28] "GET /static/css/fonts/Montserrat-Black.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:07:35] "GET /demo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:07:35] "GET /demo HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2023 00:07:35] "GET /static/css/main.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:07:35] "GET /static/css/main.css HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:07:35] "GET /static/img/logo.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:07:35] "GET /static/img/logo.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:07:36] "GET /static/img/introduction-visual.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:07:36] "GET /static/img/introduction-visual.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:07:36] "GET /static/js/functions-min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:07:36] "GET /static/js/functions-min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:07:36] "GET /static/css/fonts/Montserrat-Regular.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:07:36] "GET /static/css/fonts/Montserrat-Regular.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:07:36] "GET /static/css/fonts/Montserrat-Bold.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:07:36] "GET /static/css/fonts/Montserrat-Bold.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:07:36] "GET /static/css/fonts/Montserrat-Light.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:07:36] "GET /static/css/fonts/Montserrat-Light.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:07:36] "GET /static/css/fonts/Montserrat-Black.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:07:36] "GET /static/css/fonts/Montserrat-Black.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:08:05] "GET /demo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:08:05] "GET /demo HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2023 00:08:05] "GET /static/css/main.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:08:05] "GET /static/css/main.css HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:08:05] "GET /static/img/logo.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:08:05] "GET /static/img/logo.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:08:05] "GET /static/img/introduction-visual.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:08:05] "GET /static/img/introduction-visual.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:08:05] "GET /static/js/functions-min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:08:05] "GET /static/js/functions-min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:08:05] "GET /static/css/fonts/Montserrat-Bold.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:08:05] "GET /static/css/fonts/Montserrat-Bold.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:08:05] "GET /static/css/fonts/Montserrat-Light.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:08:05] "GET /static/css/fonts/Montserrat-Light.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:08:05] "GET /static/css/fonts/Montserrat-Regular.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:08:05] "GET /static/css/fonts/Montserrat-Regular.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:08:05] "GET /static/css/fonts/Montserrat-Black.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:08:05] "GET /static/css/fonts/Montserrat-Black.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:08:11] "GET /demo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:08:11] "GET /demo HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2023 00:08:11] "GET /static/css/main.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:08:11] "GET /static/css/main.css HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:08:11] "GET /static/img/logo.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:08:11] "GET /static/img/logo.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:08:11] "GET /static/js/functions-min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:08:11] "GET /static/js/functions-min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:08:11] "GET /static/img/introduction-visual.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:08:11] "GET /static/img/introduction-visual.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:08:11] "GET /static/css/fonts/Montserrat-Regular.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:08:11] "GET /static/css/fonts/Montserrat-Bold.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:08:11] "GET /static/css/fonts/Montserrat-Regular.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:08:11] "GET /static/css/fonts/Montserrat-Bold.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:08:11] "GET /static/css/fonts/Montserrat-Light.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:08:11] "GET /static/css/fonts/Montserrat-Light.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:08:11] "GET /static/css/fonts/Montserrat-Black.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:08:11] "GET /static/css/fonts/Montserrat-Black.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:08:20] "GET /demo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:08:20] "GET /demo HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2023 00:08:20] "GET /static/css/main.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:08:20] "GET /static/css/main.css HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:08:20] "GET /static/img/logo.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:08:20] "GET /static/img/logo.png HTTP/1.1" 304 -
# ...
#   saving_api.save_model(
# 3/3 [==============================] - 0s 1ms/step
# 127.0.0.1 - - [14/May/2023 00:18:30] "POST /demo HTTP/1.1" 302 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:18:30] "POST /demo HTTP/1.1" 302 -
# 127.0.0.1 - - [14/May/2023 00:18:30] "GET /predictions HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:18:30] "GET /predictions HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2023 00:18:30] "GET /static/css/main.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:18:30] "GET /static/css/main.css HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:18:30] "GET /static/img/introduction-visual.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:18:30] "GET /static/img/introduction-visual.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:18:30] "GET /static/img/logo.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:18:30] "GET /static/img/logo.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:18:30] "GET /static/js/functions-min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:18:30] "GET /static/js/functions-min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:18:30] "GET /%7B%20url_for('static',%20filename='img/MSFT.png')%20%7D HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:18:30] "GET /%7B%20url_for('static',%20filename='img/MSFT.png')%20%7D HTTP/1.1" 404 -
# 127.0.0.1 - - [14/May/2023 00:18:30] "GET /%7B%20url_for('static',%20filename='img/AMZN.png')%20%7D HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:18:30] "GET /%7B%20url_for('static',%20filename='img/AMZN.png')%20%7D HTTP/1.1" 404 -
# 127.0.0.1 - - [14/May/2023 00:18:30] "GET /%7B%20url_for('static',%20filename='img/NVDA.png')%20%7D HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:18:30] "GET /%7B%20url_for('static',%20filename='img/NVDA.png')%20%7D HTTP/1.1" 404 -
# 127.0.0.1 - - [14/May/2023 00:18:30] "GET /%7B%20url_for('static',%20filename='img/QQQ.png')%20%7D HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:18:30] "GET /%7B%20url_for('static',%20filename='img/QQQ.png')%20%7D HTTP/1.1" 404 -
# 127.0.0.1 - - [14/May/2023 00:18:30] "GET /%7B%20url_for('static',%20filename='img/GOOG.png')%20%7D HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:18:30] "GET /%7B%20url_for('static',%20filename='img/GOOG.png')%20%7D HTTP/1.1" 404 -
# 127.0.0.1 - - [14/May/2023 00:18:30] "GET /%7B%20url_for('static',%20filename='img/AAPL.png')%20%7D HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:18:30] "GET /%7B%20url_for('static',%20filename='img/AAPL.png')%20%7D HTTP/1.1" 404 -
# 127.0.0.1 - - [14/May/2023 00:18:30] "GET /%7B%20url_for('static',%20filename='img/SPY.png')%20%7D HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:18:30] "GET /%7B%20url_for('static',%20filename='img/SPY.png')%20%7D HTTP/1.1" 404 -
# 127.0.0.1 - - [14/May/2023 00:18:30] "GET /%7B%20url_for('static',%20filename='img/%5EDJI.png')%20%7D HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:18:30] "GET /%7B%20url_for('static',%20filename='img/%5EDJI.png')%20%7D HTTP/1.1" 404 -
# 127.0.0.1 - - [14/May/2023 00:18:30] "GET /static/css/fonts/Montserrat-Regular.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:18:30] "GET /static/css/fonts/Montserrat-Regular.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:18:30] "GET /static/css/fonts/Montserrat-Black.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:18:30] "GET /static/css/fonts/Montserrat-Black.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:18:30] "GET /static/css/fonts/Montserrat-Bold.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:18:30] "GET /static/css/fonts/Montserrat-Bold.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:18:30] "GET /static/css/fonts/Montserrat-Light.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:18:30] "GET /static/css/fonts/Montserrat-Light.woff HTTP/1.1" 304 -
# overwritten
# 127.0.0.1 - - [14/May/2023 00:18:40] "GET /demo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:18:40] "GET /demo HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2023 00:18:40] "GET /static/css/main.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:18:40] "GET /static/css/main.css HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:18:40] "GET /static/img/logo.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:18:40] "GET /static/img/logo.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:18:40] "GET /static/js/functions-min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:18:40] "GET /static/js/functions-min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:18:40] "GET /static/img/introduction-visual.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:18:40] "GET /static/img/introduction-visual.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:18:40] "GET /static/css/fonts/Montserrat-Light.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:18:40] "GET /static/css/fonts/Montserrat-Light.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:18:40] "GET /static/css/fonts/Montserrat-Bold.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:18:40] "GET /static/css/fonts/Montserrat-Bold.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:18:40] "GET /static/css/fonts/Montserrat-Regular.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:18:40] "GET /static/css/fonts/Montserrat-Regular.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:18:40] "GET /static/css/fonts/Montserrat-Black.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:18:40] "GET /static/css/fonts/Montserrat-Black.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:19:23] "GET /demo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:19:23] "GET /demo HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2023 00:19:23] "GET /static/css/main.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:19:23] "GET /static/css/main.css HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:19:23] "GET /static/img/logo.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:19:23] "GET /static/img/logo.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:19:23] "GET /static/js/functions-min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:19:23] "GET /static/js/functions-min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:19:23] "GET /static/img/introduction-visual.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:19:23] "GET /static/img/introduction-visual.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:19:23] "GET /static/css/fonts/Montserrat-Bold.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:19:23] "GET /static/css/fonts/Montserrat-Bold.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:19:23] "GET /static/css/fonts/Montserrat-Black.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:19:23] "GET /static/css/fonts/Montserrat-Black.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:19:23] "GET /static/css/fonts/Montserrat-Light.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:19:23] "GET /static/css/fonts/Montserrat-Light.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:19:23] "GET /static/css/fonts/Montserrat-Regular.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:19:23] "GET /static/css/fonts/Montserrat-Regular.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:19:43] "GET /demo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:19:43] "GET /demo HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2023 00:19:43] "GET /static/css/main.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:19:43] "GET /static/css/main.css HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:19:43] "GET /static/img/logo.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:19:43] "GET /static/img/logo.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:19:43] "GET /static/js/functions-min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:19:43] "GET /static/js/functions-min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:19:43] "GET /static/img/introduction-visual.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:19:43] "GET /static/img/introduction-visual.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:19:43] "GET /static/css/fonts/Montserrat-Light.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:19:43] "GET /static/css/fonts/Montserrat-Bold.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:19:43] "GET /static/css/fonts/Montserrat-Light.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:19:43] "GET /static/css/fonts/Montserrat-Bold.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:19:43] "GET /static/css/fonts/Montserrat-Regular.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:19:43] "GET /static/css/fonts/Montserrat-Regular.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:19:43] "GET /static/css/fonts/Montserrat-Black.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:19:43] "GET /static/css/fonts/Montserrat-Black.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:20:15] "GET /demo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:20:15] "GET /demo HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2023 00:20:16] "GET /static/css/main.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:20:16] "GET /static/css/main.css HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:20:16] "GET /static/img/logo.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:20:16] "GET /static/img/logo.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:20:16] "GET /static/js/functions-min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:20:16] "GET /static/js/functions-min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:20:16] "GET /static/img/introduction-visual.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:20:16] "GET /static/img/introduction-visual.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:20:16] "GET /static/css/fonts/Montserrat-Regular.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:20:16] "GET /static/css/fonts/Montserrat-Regular.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:20:16] "GET /static/css/fonts/Montserrat-Bold.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:20:16] "GET /static/css/fonts/Montserrat-Bold.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:20:16] "GET /static/css/fonts/Montserrat-Light.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:20:16] "GET /static/css/fonts/Montserrat-Light.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:20:16] "GET /static/css/fonts/Montserrat-Black.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:20:16] "GET /static/css/fonts/Montserrat-Black.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:20:24] "GET /demo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:20:24] "GET /demo HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2023 00:20:24] "GET /static/css/main.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:20:24] "GET /static/css/main.css HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:20:24] "GET /static/img/logo.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:20:24] "GET /static/img/logo.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:20:24] "GET /static/img/introduction-visual.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:20:24] "GET /static/img/introduction-visual.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:20:24] "GET /static/js/functions-min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:20:24] "GET /static/js/functions-min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:20:24] "GET /static/css/fonts/Montserrat-Regular.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:20:24] "GET /static/css/fonts/Montserrat-Regular.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:20:24] "GET /static/css/fonts/Montserrat-Bold.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:20:24] "GET /static/css/fonts/Montserrat-Bold.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:20:24] "GET /static/css/fonts/Montserrat-Light.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:20:24] "GET /static/css/fonts/Montserrat-Light.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:20:24] "GET /static/css/fonts/Montserrat-Black.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:20:24] "GET /static/css/fonts/Montserrat-Black.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:22:06] "GET /demo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:22:06] "GET /demo HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2023 00:22:06] "GET /static/css/main.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:22:06] "GET /static/css/main.css HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:22:06] "GET /static/img/logo.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:22:06] "GET /static/img/logo.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:22:06] "GET /static/js/functions-min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:22:06] "GET /static/js/functions-min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:22:06] "GET /static/img/introduction-visual.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:22:06] "GET /static/img/introduction-visual.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:22:06] "GET /static/css/fonts/Montserrat-Regular.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:22:06] "GET /static/css/fonts/Montserrat-Regular.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:22:06] "GET /static/css/fonts/Montserrat-Bold.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:22:06] "GET /static/css/fonts/Montserrat-Bold.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:22:06] "GET /static/css/fonts/Montserrat-Light.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:22:06] "GET /static/css/fonts/Montserrat-Light.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:22:06] "GET /static/css/fonts/Montserrat-Black.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:22:06] "GET /static/css/fonts/Montserrat-Black.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:22:36] "GET /demo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:22:36] "GET /demo HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2023 00:22:36] "GET /static/css/main.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:22:36] "GET /static/css/main.css HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:22:36] "GET /static/img/logo.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:22:36] "GET /static/img/logo.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:22:36] "GET /static/js/functions-min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:22:36] "GET /static/js/functions-min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:22:36] "GET /static/img/introduction-visual.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:22:36] "GET /static/img/introduction-visual.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:22:36] "GET /static/css/fonts/Montserrat-Bold.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:22:36] "GET /static/css/fonts/Montserrat-Bold.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:22:36] "GET /static/css/fonts/Montserrat-Regular.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:22:36] "GET /static/css/fonts/Montserrat-Regular.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:22:36] "GET /static/css/fonts/Montserrat-Light.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:22:36] "GET /static/css/fonts/Montserrat-Light.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2023 00:22:36] "GET /static/css/fonts/Montserrat-Black.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [14/May/2023 00:22:36] "GET /static/css/fonts/Montserrat-Black.woff HTTP/1.1" 304 -
